# %%
#Blackjack Game (capstone)


## The deck is unlimited in size. 
## There are no jokers. 
## The Jack/Queen/King all count as 10.
## The the Ace can count as 11 or 1.
## Use the following list as the deck of cards:

## The cards in the list have equal probability of being drawn.
## Cards are not removed from the deck as they are drawn.
## The computer is the dealer.

import random
import card

cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]


user_cards=[]
dealer_cards=[]
def give_user_hand():
    
    rand_user_1 = random.randint(0,12)
    user_card_1 = cards[rand_user_1]
    user_cards.append(user_card_1)
    return user_cards

def give_dealer_hand():
    rand_dealer_1 = random.randint(0,12)
#     rand_dealer_2 = random.randint(0,12)
    dealer_card_1 = cards[rand_dealer_1]
#     dealer_card_2 = cards[rand_dealer_2]
    dealer_cards.append(dealer_card_1)
#     dealer_cards.append(dealer_card_2)
    return dealer_cards

sum_user =0

# def sum_card_user():
        
#     for i in user_cards:
#         sum_user = sum(user_cards)
    

sum_dealer =0    
    
# def sum_card_dealer():
        
#     for i in dealer_cards:
#         sum_dealer= sum(dealer_cards)
    

play = False
user_burned = False
dealer_burned = False
while not play:
    user_play = input("Do you want to play a game of Blackjack? Type 'y' or 'n': ")
    while not user_burned and not dealer_burned:
        

        give_user_hand()
        print("Your Cards are: ", give_user_hand())
        print("Dealer's hand: " ,give_dealer_hand())
        give_dealer_hand()

    #     def sum_card_user():

    #         for i in user_cards:
    #             sum_user = sum(user_cards)

    #     def sum_card_dealer():

    #         for i in dealer_cards:
    #             sum_dealer= sum(dealer_cards)



    #     sum_card_user()
        choice=""
        while not user_burned and choice != "sit":
            if sum(user_cards) < 22:
                choice = input("hit or sit?: ")
                if choice == "hit":
                    give_user_hand()
    #                 sum(user_cards)
                    print(user_cards)
                    print(sum(user_cards))

                elif choice == "sit":
                    print(user_cards)
                    print(sum(user_cards))
            elif sum(user_cards) == 21:
                print(user_cards)
                print(sum(user_cards))
                print("BLACKJACK!!!! you Might win!")
                user_burned=True

            elif sum(user_cards) >= 22:
                user_burned=True
                print(sum(user_cards))
                print("You Got burned")


    #     sum_card_dealer() 
        dealer_sit=False
        while not dealer_burned and dealer_sit==False:
            if sum(dealer_cards) < 22:
                if sum(dealer_cards) <= 17:
                    give_dealer_hand()
    #                 sum(dealer_cards)
                    print(dealer_cards)
                    print(sum(dealer_cards))
                elif sum(dealer_cards)>17:
                    dealer_sit=True
            elif sum(dealer_cards) >= 22:
                dealer_burned=True
                print(sum(dealer_cards))
                print("dealer burned. You Win")


        if dealer_burned!=True and user_burned !=True:
            if sum(dealer_cards) == sum(user_cards):
                print(dealer_cards)
                print("push")
                dealer_burned=True
                user_burned=True
            elif sum(dealer_cards) > sum(user_cards):
                print(dealer_cards)
                print("you lose!, dealer has",sum(dealer_cards)) 
                dealer_burned=True
                user_burned=True
            elif sum(dealer_cards) < sum(user_cards):
                print(dealer_cards)
                print("you win!")
                dealer_burned=True
                user_burned=True
            elif sum(user_cards) >=22:
                print("burned. you lose!")
                dealer_burned=True
                user_burned=True
            elif sum(dealer_cards) >=22:
                print("dealer burned. You win!")
                dealer_burned=True
                user_burned=True


    if user_play == "y": 
        play = False
    elif user_play == "n":
        play = True
    
    
    
 #need to incorporate pictures to each number
 #need figure out code for when Ace is concidered as one
 #need to figure out why after hitting y again it doesnt rerun code

# %%
#Blackjack Game (capstone)


## The deck is unlimited in size. 
## There are no jokers. 
## The Jack/Queen/King all count as 10.
## The the Ace can count as 11 or 1.
## Use the following list as the deck of cards:

## The cards in the list have equal probability of being drawn.
## Cards are not removed from the deck as they are drawn.
## The computer is the dealer.

import random
import card

cards = [10, 10, 10, 10, 9 ,8 ,7 ,6 ,5 ,4 ,3 ,2 , 11]


user_cards=[]
dealer_cards=[]
def give_user_hand():
    
    rand_user_1 = random.randint(0,12)
    user_card_1 = cards[rand_user_1]
    user_cards.append(user_card_1)
    return user_cards 

def give_dealer_hand():
    rand_dealer_1 = random.randint(0,12)
#     rand_dealer_2 = random.randint(0,12)
    dealer_card_1 = cards[rand_dealer_1]
#     dealer_card_2 = cards[rand_dealer_2]
    dealer_cards.append(dealer_card_1)
#     dealer_cards.append(dealer_card_2)
    return dealer_cards and 

sum_user =0

def art_card(user_cards,dealer_cards):
    

# def sum_card_user():
        
#     for i in user_cards:
#         sum_user = sum(user_cards)
    

sum_dealer =0    
    
# def sum_card_dealer():
        
#     for i in dealer_cards:
#         sum_dealer= sum(dealer_cards)
    
user_cardpic = []
dealer_cardpic = []
play = False
user_burned = False
dealer_burned = False
while not play:
    user_play = input("Do you want to play a game of Blackjack? Type 'y' or 'n': ")
    while not user_burned and not dealer_burned:
        

        give_user_hand()
        print("Your Cards are: ", give_user_hand())
        print("Dealer's hand: " ,give_dealer_hand())
        give_dealer_hand()
        
        

    #     def sum_card_user():

    #         for i in user_cards:
    #             sum_user = sum(user_cards)

    #     def sum_card_dealer():

    #         for i in dealer_cards:
    #             sum_dealer= sum(dealer_cards)



    #     sum_card_user()
        choice=""
        while not user_burned and choice != "sit":
            if sum(user_cards) < 22:
                choice = input("hit or sit?: ")
                if choice == "hit":
                    give_user_hand()
    #                 sum(user_cards)
                    print(user_cards)
                    print(sum(user_cards))

                elif choice == "sit":
                    print(user_cards)
                    print(sum(user_cards))
            elif sum(user_cards) == 21:
                print(user_cards)
                print(sum(user_cards))
                print("BLACKJACK!!!! you Might win!")
                user_burned=True

            elif sum(user_cards) >= 22:
                user_burned=True
                print(sum(user_cards))
                print("You Got burned")


    #     sum_card_dealer() 
        dealer_sit=False
        while not dealer_burned and dealer_sit==False:
            if sum(dealer_cards) < 22:
                if sum(dealer_cards) <= 17:
                    give_dealer_hand()
    #                 sum(dealer_cards)
                    print(dealer_cards)
                    print(sum(dealer_cards))
                elif sum(dealer_cards)>17:
                    dealer_sit=True
            elif sum(dealer_cards) >= 22:
                dealer_burned=True
                print(sum(dealer_cards))
                print("dealer burned. You Win")


        if dealer_burned!=True and user_burned !=True:
            if sum(dealer_cards) == sum(user_cards):
                print(dealer_cards)
                print("push")
                dealer_burned=True
                user_burned=True
            elif sum(dealer_cards) > sum(user_cards):
                print(dealer_cards)
                print("you lose!, dealer has",sum(dealer_cards)) 
                dealer_burned=True
                user_burned=True
            elif sum(dealer_cards) < sum(user_cards):
                print(dealer_cards)
                print("you win!")
                dealer_burned=True
                user_burned=True
            elif sum(user_cards) >=22:
                print("burned. you lose!")
                dealer_burned=True
                user_burned=True
            elif sum(dealer_cards) >=22:
                print("dealer burned. You win!")
                dealer_burned=True
                user_burned=True


    if user_play == "y": 
        play = False
    elif user_play == "n":
        play = True

# %%
#Angela's Solution
import random
def deal_card():
    """
    returns a random card from the deck
    """
    cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
    card = random.choice(cards)
    return card



def calculate_score(cards):
    # checks for  blackjack
    if sum(cards)==21 and len(cards)==2:
        return 0
    #checks if there is ace in hand, and sum is over 21, so ace instead of 11 is 1
    if sum(cards)>=22 and 11 in cards:
        cards.remove(11)
        cards.append(1)
    return sum(cards)

def compare(user_score,computer_score):
    if user_score == computer_score:
        return "Push"
    elif computer_score == 0:
        return "Lose, computer has Blackjack"
    elif user_score ==0:
        return "win with a Blackjack"
    elif user_score >21:
        return "You went over. You Lose."
    elif computer_score >21:
        return "Computer went over, You win."
    elif user_score > computer_score: 
        return "you win"
    else:
        return "you lose"
def play_game():
    user_cards =[]
    computer_cards=[]
    is_game_over=False
    
    for _ in range(2):
        user_cards.append(deal_card())
        computer_cards.append(deal_card())

    while not is_game_over:    
        user_score = calculate_score(user_cards)
        computer_score = calculate_score(computer_cards) 
        print(f" Your Cards: {user_cards}, current score: {user_score}")
        print(f" Computer's Cards: {computer_cards[0]}")


        if user_score==0 or computer_score==0 or user_score > 21:
            is_game_over = True
        else: 
            user_should_deal = input("Type 'y' to get another card or 'n' to pass: ")
            if user_should_deal == "y":
                user_cards.append(deal_card())
            else:
                is_game_over = True


    while computer_score!=0 and computer_score<17:
        computer_cards.append(deal_card())
        computer_score = calculate_score(computer_cards)
        print(f" Computer's Cards: {computer_cards}, current score: {computer_score}")

    print(f" your final hand: {user_cards}, your final score: {user_score}")
    print(f" computer final hand: {computer_cards}, computer final score: {computer_score}")
    print(compare(user_score,computer_score))
    
while input("Do you want to play a game of blackjack? Type 'y' or 'n': ") == "y":
    play_game()
# Out:
# Do you want to play a game of blackjack? Type 'y' or 'n': y
#  Your Cards: [5, 2], current score: 7
#  Computer's Cards: 2
# Type 'y' to get another card or 'n' to pass: y
#  Your Cards: [5, 2, 9], current score: 16
#  Computer's Cards: 2
# Type 'y' to get another card or 'n' to pass: y
#  Your Cards: [5, 2, 9, 5], current score: 21
#  Computer's Cards: 2
# Type 'y' to get another card or 'n' to pass: n
#  Computer's Cards: [2, 5, 11], current score: 18
#  your final hand: [5, 2, 9, 5], your final score: 21
#  computer final hand: [2, 5, 11], computer final score: 18
# you win
# Do you want to play a game of blackjack? Type 'y' or 'n': y
#  Your Cards: [11, 1], current score: 12
#  Computer's Cards: 10
# Type 'y' to get another card or 'n' to pass: y
#  Your Cards: [1, 10, 1], current score: 12
#  Computer's Cards: 10
# Type 'y' to get another card or 'n' to pass: y
#  Your Cards: [1, 10, 1, 10], current score: 22
#  Computer's Cards: 10
# ...
